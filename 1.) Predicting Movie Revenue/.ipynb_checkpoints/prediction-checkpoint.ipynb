# %%
# !pip install pandas
# !pip install matplotlib
# Out:
# Requirement already satisfied: pandas in /home/raghavgupta/.local/lib/python3.9/site-packages (1.3.1)
# Requirement already satisfied: numpy>=1.17.3 in /home/raghavgupta/.local/lib/python3.9/site-packages (from pandas) (1.21.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/lib/python3/dist-packages (from pandas) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/raghavgupta/.local/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: matplotlib in /home/raghavgupta/.local/lib/python3.9/site-packages (3.4.2)
# Requirement already satisfied: cycler>=0.10 in /home/raghavgupta/.local/lib/python3.9/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/raghavgupta/.local/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/raghavgupta/.local/lib/python3.9/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/raghavgupta/.local/lib/python3.9/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /home/raghavgupta/.local/lib/python3.9/site-packages (from matplotlib) (8.3.1)
# Requirement already satisfied: numpy>=1.16 in /home/raghavgupta/.local/lib/python3.9/site-packages (from matplotlib) (1.21.1)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from cycler>=0.10->matplotlib) (1.15.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/media/raghavgupta/New Volume/courses/data Science/2. Predict Movie Box Office Revenue with Linear Regression/dirtyData.csv')

# %%
data.head()
# Out:
#    Rank Release Date            Movie Title Production Budget ($)  \
# 0  4840     6/1/2012       The Devil Inside            $1,000,000
# 1  4841    7/10/1963              Tom Jones            $1,000,000
# 2  4842    4/17/2015             Unfriended            $1,000,000
# 3  4843     8/2/1976            Taxi Driver            $1,000,000
# 4  4844    5/24/2006  An Inconvenient Truth            $1,000,000
#
#   Worldwide Gross ($) Domestic Gross ($) Unnamed: 6
# 0        $101,759,490        $53,262,945        NaN
# 1         $37,600,000        $37,600,000        NaN
# 2         $62,561,449        $32,482,090        NaN
# 3         $28,316,211        $28,262,574        NaN
# 4         $52,769,915        $24,146,161        NaN

# %%
budget = []
earning = []
for i in data['Production Budget ($)']:
    temp = ''
    for j in i:
        if(j==',' or j=='$'):
            continue
        else:
            temp+=j
#     budget.append(temp)
    budget.append(int(temp))
for i in data['Worldwide Gross ($)']:
    temp = ''
    for j in i:
        if(j==',' or j=='$'):
            continue
        else:
            temp+=j
#     budget.append(temp)
    earning.append(int(temp))
budget = np.asanyarray(budget)
earning = np.asanyarray(earning)

# %%
#till this point, we have an array named budget and earning with all the clean data

# %%
plt.figure(figsize=(20,12))
plt.scatter(budget,earning,alpha=0.3) # budget is on x axis and earning is on y axis
plt.title("Film Cost vs revenue")
plt.xlabel("Production Budget $")
plt.ylabel("Earning $")
plt.ylim(0,3000000000)
plt.xlim(0,450000000)
plt.show()
# plt.axes('Earning','Movie Budget')

# %%
'''
Till now we have analyised from the above chart that movies with smaller budget have less revenue
'''
# Out:
# '\nTill now we have analyised from the above chart that movies with smaller budget have less revenue\n'
